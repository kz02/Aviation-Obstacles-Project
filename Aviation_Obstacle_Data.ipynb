# %%
#Kelsey Zubiate
#tpe010

# %% [markdown]
# ## Aviation Obstacle Data Visualization Project
# The original data can be located at: https://www.faa.gov/air_traffic/flight_info/aeronav/digital_products/DailyDOF/
#
# The data for this project was accessed 10/29/2025
#
# This project will take data from the FAA website titled Daily Digital Obstacle File (DOF). The DOF tracks obstacles locations and basic descriptions for aviation users. This project will only look into the state of Texas obstacles and display two visualizations to detail the data.

# %%
#Import pandas
import pandas as pd

#Import csv file and create a dataframe
df_DOF = pd.read_csv('DOF.csv')
#Clean the data by removing NA's
df_clean = df_DOF.dropna()
#Display the Dataframe
display(df_clean)
# Out:
#               OAS VERIFIED STATUS COUNTRY STATE              CITY     LATDEC  \
# 0       01-001307               O      US    AL  DAUPHIN ISLAND    30.179167
# 1       01-001459               O      US    AL  DAUPHIN ISLAND    30.188889
# 2       01-001472               O      US    AL  FORT MORGAN       30.188889
# 3       01-002567               O      US    AL  GULF SHORES       30.230278
# 4       01-002558               O      US    AL  GULF SHORES       30.230278
# ...           ...             ...     ...   ...               ...        ...
# 623547  VI-020012               O      VI        CHARLOTTE AMALIE  18.356850
# 623548  VI-000038               O      VI        CHARLOTTE AMALIE  18.356868
# 623549  VI-000919               U      VI        CHARLOTTEAMALIE   18.357734
# 623550  VI-020013               O      VI        CRUZ BAY          18.373945
# 623551  WS-000160               O      WS        SAMOA            -13.816667
#
#             LONDEC        DMSLAT         DMSLON                TYPE  QUANTITY  \
# 0       -88.077500  30 10 45.00N  088 04 39.00W  RIG                        1
# 1       -88.120834  30 11 20.00N  088 07 15.00W  RIG                        1
# 2       -87.952778  30 11 20.00N  087 57 10.00W  STACK                      1
# 3       -87.873612  30 13 49.00N  087 52 25.00W  BLDG                       1
# 4       -87.875000  30 13 49.00N  087 52 30.00W  BLDG                       1
# ...            ...           ...            ...                 ...       ...
# 623547  -64.971309  18 21 24.66N  064 58 16.71W  TOWER                      1
# 623548  -64.970062  18 21 24.72N  064 58 12.22W  TOWER                      1
# 623549  -64.971509  18 21 27.84N  064 58 17.43W  TOWER                      1
# 623550  -64.928639  18 22 26.20N  064 55 43.10W  TOWER                      1
# 623551 -171.833334  13 49 00.00S  171 50 00.00W  TOWER                      2
#
#         AGL  AMSL LIGHTING ACCURACY MARKING       FAA STUDY ACTION    JDATE
# 0       236   236        R       5D       M  1990ASO01578OE      C  2014138
# 1       240   241        R       5D       M  1992ASO02229OE      C  2014138
# 2       193   193        R       5D       M  1992ASO02230OE      C  2014138
# 3       223   242        R       5D       N  2000ASO03180OE      C  2004005
# 4       223   242        R       5D       N  1999ASO03256OE      C  2004005
# ...     ...   ...      ...      ...     ...             ...    ...      ...
# 623547  192  1730        D       2C       N  2017ASO22333OE      C  2018249
# 623548  250  1732        D       2C       N  2014ASO10698OE      C  2016153
# 623549  245  1690        D       4D       N  2002ASO05614OE      C  2014124
# 623550   29   274        N       2C       N  2010ASO01020OE      A  2015282
# 623551  407   447        U       9I       U                      C  1999032
#
# [623552 rows x 19 columns]
